# %%
# !pip install pydub
#!sudo apt-get install libportaudio2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np

# %%
directory = '/content/drive/MyDrive/SIC_Final_Project/train_audio'
subdirectory = []
species = []

for filename in os.listdir(directory):
  subdirectory.append(os.path.join(directory, filename))
  species.append(filename)
subdirectory.sort()
species.sort()

# %%
# %time
i= -1
for folder in subdirectory:
  os.chdir(folder)
  i += 1
  j = 0
  for audiofile in os.listdir(folder):
    print(audiofile,species[i])
    sound = AudioSegment.from_ogg(audiofile)
    path = os.path.join("/content/drive/MyDrive/SIC_Final_Project/train_audio(wav)",species[i])
    os.chdir(path)
    sound.export(f"{species[i]}({j}).wav", format="wav")
    os.chdir(folder)
    j +=1
os.chdir("/content")
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# XC629332.ogg normoc
# XC627759.ogg normoc
# XC608453.ogg normoc
# XC599233.ogg normoc
# XC627756.ogg normoc
# XC608485.ogg normoc
# XC610095.ogg normoc
# XC608253.ogg normoc
# XC608255.ogg normoc
# XC604464.ogg normoc
# XC627304.ogg normoc
# XC616859.ogg normoc
# XC601585.ogg normoc
# XC590833.ogg normoc
# XC582706.ogg normoc
# XC574088.ogg normoc
# XC567445.ogg normoc
# XC58466.ogg normoc
# XC58465.ogg normoc
# XC570555.ogg normoc
# XC574056.ogg normoc
# XC57040.ogg normoc
# XC570237.ogg normoc
# XC582732.ogg normoc
# XC582708.ogg normoc
# XC566099.ogg normoc
# XC553299.ogg normoc
# XC554502.ogg normoc
# XC545900.ogg normoc
# XC565200.ogg normoc
# XC552447.ogg normoc
# XC554505.ogg normoc
# XC554503.ogg normoc
# XC554499.ogg normoc
# XC559555.ogg normoc
# XC554557.ogg normoc
# XC554501.ogg normoc
# XC541426.ogg normoc
# XC534181.ogg normoc
# XC511451.ogg normoc
# XC534762.ogg normoc
# XC545024.ogg normoc
# ...

# %%
for code in species:
  path = os.path.join("/content/drive/MyDrive/SIC_Final_Project/train_audio(wav)", code)
  os.mkdir(path)

# %%
# Separa Audio Stereo em audios Mono
s_rate, signal = wavfile.read()

if signal[0].size == 2:
  signal1 = signal[:,0]
  signal2 = signal[:,1]
sound.export(, format="wav")

# %%
s_rate, signal = wv.read() 
print(signal)

signal1 = signal[:,0] #laranja
signal2 = signal[:,1] #azul

wv.write("bird1mono1.wav",s_rate,signal)

plt.plot(signal[:,0])
#plt.plot(signal)
plt.axis('off')
plt.show
